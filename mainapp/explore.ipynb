# %%
pip install yahoo-fin
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# ...
#   Using cached feedparser-6.0.11-py3-none-any.whl (81 kB)
# ...
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# ...
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pyquery-2.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# ...
#   Using cached parse-1.20.2-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached pyppeteer-2.0.0-py3-none-any.whl (82 kB)
# ...
#   Using cached fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# ...
#   Using cached w3lib-2.2.1-py3-none-any.whl (21 kB)
# ...
#   Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# ...
#   Using cached pyee-11.1.0-py3-none-any.whl (15 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# ...
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# ...

# %%
import pandas as pd  
url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download'
    # Lendo os dados do URL
df = pd.read_csv(url)
    # Retornando a lista de tickers
return df['Symbol'].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download'
#       3     # Lendo os dados do URL
# ----> 4 df = pd.read_csv(url)
#       5     # Retornando a lista de tickers
#       6 return df['Symbol'].tolist()
#
# File ~/desafio/stockproject/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/desafio/stockproject/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
ticker_obj = yf.Ticker('NFLX')    
ticker_info =ticker_obj.info
    ## Historical Data
hist_df = ticker_obj.history(period="1y")
hist_df = hist_df.reset_index()
    ## News Data
news_data = [{"title": entry["title"], "link": entry["link"], "publisher": entry["publisher"]} for entry in ticker_obj.news]
hist_df
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2023-07-10 00:00:00-04:00  438.519989  444.410004  436.820007  441.709991
# 1   2023-07-11 00:00:00-04:00  438.649994  440.799988  431.040009  440.209991
# 2   2023-07-12 00:00:00-04:00  444.549988  445.410004  437.750000  444.049988
# 3   2023-07-13 00:00:00-04:00  447.000000  451.670013  441.179993  450.380005
# 4   2023-07-14 00:00:00-04:00  452.790009  456.480011  439.700012  441.910004
# ..                        ...         ...         ...         ...         ...
# 246 2024-07-01 00:00:00-04:00  674.890015  675.020020  663.780029  673.609985
# 247 2024-07-02 00:00:00-04:00  673.539978  681.739990  670.070007  679.580017
# 248 2024-07-03 00:00:00-04:00  677.479980  683.750000  675.500000  682.510010
# 249 2024-07-05 00:00:00-04:00  682.510010  697.489990  677.229980  690.650024
# 250 2024-07-08 00:00:00-04:00  686.590027  688.716980  681.484985  684.630005
#
# ...

# %%
def get_periods():
    # Define the periods you want to include
    periods = ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
    return periods

print(get_periods())
# Out:
# ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']

# %%
 stocks = Stock.objects.all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 stocks = Stock.objects.all()
#
# NameError: name 'Stock' is not defined
